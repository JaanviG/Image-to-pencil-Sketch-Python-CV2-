# %% [markdown]
# # Task:- Image to pencil Sketch with Python

# %% [markdown]
# ### Author :- Janvi Gulhane

# %% [markdown]
# ## Problem Statement:-
# * We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo.
# * Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image.
# * This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# ## Importing required Libraries

# %%
import cv2
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %% [markdown]
# ## Loading and ploting the original Image

# %% [markdown]
# Using cv2 library from python to convert the RGB image to gray scale image
# ### Note: RGB stands for red, green, blue. The RGB color model is additive: red, green, and blue light are added together in varying proportions to produce an extensive range of colors.

# %%
img = cv2.imread("E:\Jyputer\dog.jpg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.axis("off")
plt.title("Original Image", fontsize=20)
plt.show()

# %% [markdown]
#  We have imported the original Image and displayed it.

# %% [markdown]
# ## Coverting Image to GrayScale

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(10,10))
plt.imshow(img_gray, cmap = "gray")
plt.axis("off")
plt.title("GrayScale Image", fontsize=20)
plt.show()

# %% [markdown]
# ### We have converted the original Image to GrayScale image and displayed it.

# %% [markdown]
# ## Inveting the Image

# %%
img_inv = cv2.bitwise_not(img_gray)
plt.figure(figsize=(10,10))
plt.imshow(img_inv, cmap = "gray")
plt.axis("off")
plt.title("Inverted Image",fontsize=20)
plt.show()

# %% [markdown]
# ### We have converted the Grayscale Image into inverted Image.

# %% [markdown]
# ## Smoothing the Image

# %%
img_smoo = cv2.GaussianBlur(img_inv, (21,21), sigmaX= 0, sigmaY= 0)
plt.figure(figsize=(10,10))
plt.imshow(img_smoo, cmap = "gray")
plt.axis("off")
plt.title("Smoothen Image", fontsize = 20)
plt.show()

# %% [markdown]
# ### We used gaussianBlur to Smoothen the Image from the inverted one.

# %% [markdown]
# ## Coverting the Image to pencil Sketch

# %%
final = cv2.divide(img_gray, 255 - img_smoo, scale = 255)
plt.figure(figsize=(10,10))
plt.imshow(final, cmap = "gray")
plt.axis("off")
plt.title("Final Image", fontsize = 20)
plt.show()

# %% [markdown]
# ### Finally We got the Sketched image from the smoothen Image

# %% [markdown]
# ### Steps which we followed.
# 1. Convert the color image to grayscale.
#
# 2. Invert the grayscale image to get a negative(invert image).
#
# 3. Apply a Gaussian blur() to the negative from previous step.
#
# 4. Finally by using divide get the sketch image from the smoothen Image.

# %% [markdown]
# ## Using the above mentioned steps we successfully got Grayscaled Image.
